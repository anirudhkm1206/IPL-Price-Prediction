# %%
import pandas as pd
import numpy as np

# %%
ipl_df = pd.read_csv("IPL IMB381IPL2013.csv")

# %%
ipl_df.head(50)
# Out:
#     Sl.NO.        PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  \
# 0        1        Abdulla, YA    2      SA   KXIP   Allrounder       0
# 1        2       Abdur Razzak    2     BAN    RCB       Bowler     214
# 2        3        Agarkar, AB    2     IND    KKR       Bowler     571
# 3        4          Ashwin, R    1     IND    CSK       Bowler     284
# 4        5       Badrinath, S    2     IND    CSK      Batsman      63
# 5        6         Bailey, GJ    2     AUS    CSK      Batsman       0
# 6        7          Balaji, L    2     IND   CSK+       Bowler      51
# 7        8      Bollinger, DE    2     AUS    CSK       Bowler      54
# 8        9           Botha, J    2      SA     RR   Allrounder      83
# 9       10        Boucher, MV    2      SA   RCB+    W. Keeper    5515
# 10      11          Bravo, DJ    2      WI    MI+   Allrounder    2200
# 11      12     Chanderpaul, S    3      WI    RCB      Batsman    9918
# ...

# %%
ipl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline

# %%
ipl_df['PREMIUM'] = ipl_df['SOLD PRICE']-ipl_df['BASE PRICE']

# %%
sn.barplot(x='AGE', y='PREMIUM', data=ipl_df, hue='PLAYING ROLE')
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='PREMIUM'>

# %%
plt.hist(ipl_df['AGE'], bins=3)
# Out:
# (array([16., 86., 28.]),
#  array([1.        , 1.66666667, 2.33333333, 3.        ]),
#  <BarContainer object of 3 artists>)

# %%
sn.distplot(ipl_df['AGE'])
# Out:
# /Users/anirudhkrishnamurthy/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='AGE', ylabel='Density'>

# %%
box = plt.boxplot(ipl_df['T-RUNS'])

# %%
ipl_df[['PLAYER NAME', 'T-RUNS', 'SOLD PRICE']].sort_values('SOLD PRICE', ascending=False)[0:30]
# Out:
#          PLAYER NAME  T-RUNS  SOLD PRICE
# 93         Sehwag, V    8178     1800000
# 127     Yuvraj Singh    1775     1800000
# 50          Kohli, V     491     1800000
# 111    Tendulkar, SR   15470     1800000
# 113       Tiwary, SS       0     1600000
# 83     Pietersen, KP    6654     1550000
# 23       Flintoff, A    3845     1550000
# 15         Dhoni, MS    3509     1500000
# 108       Symonds, A    1462     1350000
# 110     Taylor, LRPL    2742     1000000
# 41    Jayasuriya, ST    6973      975000
# 39        Jadeja, RA       0      950000
# 59       Mathews, AD    1219      950000
# 95         Sharma, I     432      950000
# 8           Botha, J      83      950000
# 81        Pathan, IK    1105      925000
# 55            Lee, B    1451      900000
# 44        Kallis, JH   12379      900000
# 101        Singh, RP     116      875000
# 72          Nehra, A      77      850000
# 3          Ashwin, R     284      850000
# 30   Harbhajan Singh    2164      850000
# ...

# %%
ipl_df.columns
# Out:
# Index(['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE',
#        'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE', 'PREMIUM'],
#       dtype='object')

# %%
[item.get_ydata()[0] for item in box['caps']]
# Out:
# [0.0, 7212.0]

# %%
[item.get_ydata()[0] for item in box['whiskers']]
# Out:
# [25.5, 3002.25]

# %%
[item.get_ydata()[0] for item in box['medians']]
# Out:
# [542.5]

# %%
sn.distplot(ipl_df[ipl_df['CAPTAINCY EXP']==1]['SOLD PRICE'], color='y', label='Captaincy Experience')
sn.distplot(ipl_df[ipl_df['CAPTAINCY EXP']==0]['SOLD PRICE'], color='r', label='No captaincy Experience')
plt.legend()
# Out:
# /Users/anirudhkrishnamurthy/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/anirudhkrishnamurthy/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sn.boxplot(x='PLAYING ROLE', y='SOLD PRICE', data = ipl_df)
# Out:
# <AxesSubplot:xlabel='PLAYING ROLE', ylabel='SOLD PRICE'>

# %%
ipl_batsmen_df = ipl_df[ipl_df['PLAYING ROLE'] == 'Batsman']

# %%
plt.scatter(x = ipl_batsmen_df.SIXERS, y= ipl_batsmen_df['SOLD PRICE'])

# %%
from scipy.stats import zscore

# %%
ipl_df['Z-SCORE'] = zscore(ipl_df['ODI-SR-B'])

# %%
ipl_df.drop('Z-SCORE', inplace=True,  axis=1)

# %%
ipl_df.columns
# Out:
# Index(['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE',
#        'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE', 'PREMIUM'],
#       dtype='object')

# %%
categorical_features = ['AGE', 'COUNTRY',  'PLAYING ROLE', 'CAPTAINCY EXP']
X_features = ['AGE', 'COUNTRY', 'PLAYING ROLE', 'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL', 'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C', 'WKTS', 'AVE-BL', 'ECON', 'SR-BL']

# %%
ipl_encoded_df = pd.get_dummies(ipl_df[X_features], columns=categorical_features, drop_first=True)

# %%
X_features = ipl_encoded_df.columns

# %%
import statsmodels.api as sm
from sklearn.model_selection import train_test_split

# %%
X = ipl_encoded_df
Y = ipl_df['SOLD PRICE']

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_scaler = StandardScaler()
X_scaled = X_scaler.fit_transform(X)
Y=(Y-Y.mean())/Y.std()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.8, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression

# %%
linreg = LinearRegression()
linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
linreg.coef_
# Out:
# array([-1.32222365e-04, -3.25944756e-04,  1.42475193e-04, -1.28843535e-03,
#         2.00437485e-03, -1.90092238e-03,  2.82002149e-04, -1.35600681e-02,
#         5.29987373e-02, -3.25638605e-03,  1.04818659e-02,  1.71641490e-04,
#         7.55945579e-03,  1.27405109e-02, -1.67666047e-02, -1.88266248e-02,
#        -5.67265182e-01, -5.32996958e-01, -3.00150721e-01,  1.65289728e+00,
#         3.81768915e-01,  4.77422326e-01,  1.86628306e-01,  1.58019242e-01,
#         4.26741379e-02,  2.60756822e-02, -3.57649582e-01,  1.86144041e-01,
#         3.78456171e-02, -1.75411353e-01,  4.03417973e-01])

# %%
columns_coef_df = pd.DataFrame({'columns': ipl_encoded_df.columns, 'coef': linreg.coef_})

# %%
sorted_coef_vals = columns_coef_df.sort_values('coef', ascending=False)

# %%
plt.figure(figsize=(8,6))
sn.barplot(x='coef', y='columns', data=sorted_coef_vals)
plt.xlabel('Coeffecients from Linear Regression')
plt.ylabel('Features')
# Out:
# Text(0, 0.5, 'Features')

# %%
def get_vif_factors(X):
    X_matrix = X.to_numpy()
    vif = [variance_inflation_factor(X_matrix, i) for i in range(X_matrix.shape[1])]
    vif_factors = pd.DataFrame()
    vif_factors['column'] = X.columns
    vif_factors['vif'] = vif
    return vif_factors

# %%
vif_factors = get_vif_factors(X[X_features])

# %%
vif_factors
# Out:
#                     column         vif
# 0                   T-RUNS   12.612694
# 1                   T-WKTS    7.679284
# 2               ODI-RUNS-S   16.426209
# 3                 ODI-SR-B   13.829376
# 4                 ODI-WKTS    9.951800
# 5                ODI-SR-BL    4.426818
# 6                   RUNS-S   16.135407
# 7                       HS   22.781017
# 8                      AVE   25.226566
# 9                     SR-B   21.576204
# 10                  SIXERS    9.547268
# 11                  RUNS-C   38.229691
# 12                    WKTS   33.366067
# 13                  AVE-BL  100.198105
# 14                    ECON    7.650140
# 15                   SR-BL  103.723846
# 16                   AGE_2    6.996226
# 17                   AGE_3    3.855003
# 18             COUNTRY_BAN    1.469017
# 19             COUNTRY_ENG    1.391524
# 20             COUNTRY_IND    4.568898
# 21              COUNTRY_NZ    1.497856
# 22             COUNTRY_PAK    1.796355
# ...

# %%
columns_with_large_vif = vif_factors[vif_factors.vif>4].column

# %%
plt.figure(figsize = (12, 10))
sn.heatmap(X[columns_with_large_vif].corr(), annot=True)
plt.title("Heatmap between vif features")
# Out:
# Text(0.5, 1.0, 'Heatmap between vif features')

# %%
columns_to_be_removed = ['T-RUNS', 'T-WKTS', 'RUNS-S', 'HS', 'AVE', 'RUNS-C', 'SR-B', 'AVE-BL', 'ECON', 'ODI-SR-B', 'ODI-RUNS-S', 'AGE-2', 'SR-BL']

# %%
X_new_features = list(set(X_features)-set(columns_to_be_removed))

# %%
get_vif_factors(X[X_new_features])
# Out:
#                     column       vif
# 0          CAPTAINCY EXP_1  2.458745
# 1      PLAYING ROLE_Bowler  3.174121
# 2                    AGE_2  4.629426
# 3              COUNTRY_BAN  1.109963
# 4               COUNTRY_SA  1.639204
# 5     PLAYING ROLE_Batsman  3.074394
# 6                     WKTS  2.951596
# 7               COUNTRY_SL  1.594792
# 8              COUNTRY_IND  3.291105
# 9                    AGE_3  2.721214
# 10              COUNTRY_WI  1.300381
# 11                ODI-WKTS  2.842962
# 12                  SIXERS  2.399054
# 13             COUNTRY_ENG  1.201517
# 14             COUNTRY_PAK  1.453107
# 15              COUNTRY_NZ  1.290160
# 16             COUNTRY_ZIM  1.209373
# 17               ODI-SR-BL  2.876269
# 18  PLAYING ROLE_W. Keeper  2.164214

# %%
X_train = X_train[X_new_features]

# %%
linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
significant_vars = ['COUNTRY_IND', 'COUNTRY_ENG', 'SIXERS', 'CAPTAINCY EXP_1']
train_X = train_X[significant_vars]
ipl_model_3 = sm.OLS(train_y, train_X).fit()

# %%
ipl_model_3.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                         Results: Ordinary least squares
# ...
# Model:                  OLS              Adj. R-squared (uncentered): 0.704
# Dependent Variable:     SOLD PRICE       AIC:                         2961.8089
# Date:                   2021-12-09 02:22 BIC:                         2972.3864
# No. Observations:       104              Log-Likelihood:              -1476.9
# Df Model:               4                F-statistic:                 62.77
# Df Residuals:           100              Prob (F-statistic):          1.97e-26
# R-squared (uncentered): 0.715            Scale:                       1.3164e+11
# --------------------------------------------------------------------------------
#                      Coef.      Std.Err.    t    P>|t|     [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
def draw_pp_plot(model, title):
    probPlot = sm.ProbPlot(model.resid)
    plt.figure(figsize=(8,6))
    probPlot.ppplot(line='45')
    plt.title(title)
    plt.show()

# %%
draw_pp_plot(ipl_model_3, "PP plot")

# %%
def plot_resid_fitted(fitted, resid, title):
    plt.scatter((fitted), resid)
    plt.title(title)
    plt.xlabel("Standardized predicted values")
    plt.ylabel("Standardized residual values")
    plt.show()

# %%
plot_resid_fitted(ipl_model_3.fittedvalues, ipl_model_3.resid, "Residual Plot")
